# %%
import numpy as np

# %%
array1= np.array([0,1,2,3,4,5])
print(array1)
print(array1+5)
print(np.sum(array1))
print(np.average(array1))
# Out:
# [0 1 2 3 4 5]
# [ 5  6  7  8  9 10]
# 15
# 2.5

# %%
import matplotlib .pyplot as plt
import numpy as np

xpoints = np.array([0,5])
ypoints = np.array([0,5])


plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints =np.array([12,23,45])
plt.plot(xpoints)
plt.show()

# %%
import pandas as pd

# %%
student = {'roll_no': '101', '102' ,
 'student_name': "rohan","jaya"
 }
# Out:
#   Cell In[3], line 1
#     student = {'roll_no': '101', '102' ,
#                                      ^
# SyntaxError: ':' expected after dictionary key

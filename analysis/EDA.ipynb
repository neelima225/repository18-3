# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# Data ingestion

# %%
path =r"D:\python_notes2\theroy\laptopPrice (1).csv"
print(path)
# Out:
# D:\python_notes2\theroy\laptopPrice (1).csv

# %%
import pandas as pd
file2 = pd.read_csv(path)
file2
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
file2.isna().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
file2.duplicated().sum()
# Out:
# np.int64(21)

# %%
file2= file2.drop_duplicates(keep= "first").reset_index(drop=type)
file2
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 797    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 798    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 799    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 800    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 801  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
file2 = file2.drop_duplicates(keep ="first").reset_index(drop=True)
file2
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 797    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 798    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 799    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 800    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 801  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
file2.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
file2.dtypes
# Out:
# brand                object
# processor_brand      object
# processor_name       object
# processor_gnrtn      object
# ram_gb               object
# ram_type             object
# ssd                  object
# hdd                  object
# os                   object
# os_bit               object
# graphic_card_gb      object
# weight               object
# warranty             object
# Touchscreen          object
# msoffice             object
# Price                 int64
# rating               object
# Number of Ratings     int64
# Number of Reviews     int64
# dtype: object

# %%
cat = list(file2.columns[file2.dtypes =="object"])
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
con = list(file2.columns[file2.dtypes != "object"])
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
file2["Price"]
# Out:
# 0       34649
# 1       38999
# 2       39999
# 3       69990
# 4       26990
#         ...
# 797    135990
# 798    144990
# 799    149990
# 800    142990
# 801     57490
# Name: Price, Length: 802, dtype: int64

# %%
file2.agg({"Price":"sum"})
# Out:
# Price    61453686
# dtype: int64

# %%
cat =list(file2.columns[file2.dtypes=="object"])
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
graph1=file2.groupby(by ="brand")\
.agg({"Price":"sum"})
graph1
# Out:
#            Price
# brand
# APPLE    3612870
# ASUS    19300523
# Avita     338079
# DELL     9057554
# HP      10015077
# Lenovo  10500510
# MSI      4935651
# acer     3693422

# %%
graph1.plot(kind= "barh")
# Out:
# <Axes: ylabel='brand'>

# %%
con = list(file2.columns[file2.dtypes !="object"])
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']
